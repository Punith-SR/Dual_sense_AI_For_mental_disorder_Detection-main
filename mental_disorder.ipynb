# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img, img_to_array
import os
picture_size = 48
folder_path = r"C:\2 manasa\MENTAL_DISORDER DISORDER\DATASETS"
expression = 'stress'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"/train/"+expression+"/"+
                  os.listdir(folder_path + "/train/" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Parameters
batch_size = 128
picture_size = 48
folder_path = r"C:\2 manasa\MENTAL_DISORDER DISORDER\DATASETS"  # Change if needed

# Paths joined correctly using os.path.join
train_path = os.path.join(folder_path, "train")
test_path = os.path.join(folder_path, "test")

# Data generator with augmentation for training
datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Data generator for validation/testing (no augmentation)
datagen_val = ImageDataGenerator(rescale=1./255)

# Create train data loader with augmentation
train_set = datagen_train.flow_from_directory(
    train_path,
    target_size=(picture_size, picture_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Create test data loader without augmentation
test_set = datagen_val.flow_from_directory(
    test_path,
    target_size=(picture_size, picture_size),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 5000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.

# %%
from keras.optimizers import Adam,SGD,RMSprop
from keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
from keras.models import Model,Sequential
from keras.optimizers import Adam,SGD,RMSprop


no_of_classes = 5

model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(5, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# c:\Users\punit\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_14 (Conv2D)              │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 44, 44, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 20, 20, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,488,069 (9.49 MB)
#  Trainable params: 2,488,069 (9.49 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
from keras.optimizers import RMSprop,SGD,Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint("./model.keras", monitor='val_acc', verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_learningrate = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)

callbacks_list = [early_stopping,checkpoint,reduce_learningrate]

epochs = 48

model.compile(loss='categorical_crossentropy',
              optimizer = Adam(learning_rate=0.0001),

              metrics=['accuracy'])
history = model.fit(
    train_set,
    epochs=epochs,
    validation_data=test_set,
    callbacks=callbacks_list,
    class_weight=None
)
# Out:
# c:\Users\punit\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 12s 263ms/step - accuracy: 0.1982 - loss: 4.1188 - val_accuracy: 0.2240 - val_loss: 1.6364 - learning_rate: 1.0000e-04
# Epoch 2/48
# c:\Users\punit\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\model_checkpoint.py:276: UserWarning: Can save best model only with val_acc available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.2206 - loss: 1.7507 - val_accuracy: 0.2644 - val_loss: 1.5927 - learning_rate: 1.0000e-04
# Epoch 3/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 0.2290 - loss: 1.6537 - val_accuracy: 0.2910 - val_loss: 1.5727 - learning_rate: 1.0000e-04
# Epoch 4/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 260ms/step - accuracy: 0.2438 - loss: 1.6132 - val_accuracy: 0.3184 - val_loss: 1.5591 - learning_rate: 1.0000e-04
# Epoch 5/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step - accuracy: 0.2676 - loss: 1.5955 - val_accuracy: 0.3232 - val_loss: 1.5475 - learning_rate: 1.0000e-04
# Epoch 6/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 12s 289ms/step - accuracy: 0.2714 - loss: 1.5799 - val_accuracy: 0.3524 - val_loss: 1.5314 - learning_rate: 1.0000e-04
# Epoch 7/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 282ms/step - accuracy: 0.2886 - loss: 1.5676 - val_accuracy: 0.3420 - val_loss: 1.5251 - learning_rate: 1.0000e-04
# Epoch 8/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 284ms/step - accuracy: 0.3076 - loss: 1.5482 - val_accuracy: 0.3634 - val_loss: 1.4976 - learning_rate: 1.0000e-04
# Epoch 9/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 278ms/step - accuracy: 0.3230 - loss: 1.5234 - val_accuracy: 0.3780 - val_loss: 1.4790 - learning_rate: 1.0000e-04
# Epoch 10/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 12s 297ms/step - accuracy: 0.3286 - loss: 1.5188 - val_accuracy: 0.3800 - val_loss: 1.4711 - learning_rate: 1.0000e-04
# Epoch 11/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 12s 289ms/step - accuracy: 0.3404 - loss: 1.5008 - val_accuracy: 0.4102 - val_loss: 1.4443 - learning_rate: 1.0000e-04
# Epoch 12/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 278ms/step - accuracy: 0.3618 - loss: 1.4793 - val_accuracy: 0.4162 - val_loss: 1.4315 - learning_rate: 1.0000e-04
# Epoch 13/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 260ms/step - accuracy: 0.3664 - loss: 1.4745 - val_accuracy: 0.4166 - val_loss: 1.4099 - learning_rate: 1.0000e-04
# Epoch 14/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 259ms/step - accuracy: 0.3732 - loss: 1.4487 - val_accuracy: 0.4266 - val_loss: 1.3916 - learning_rate: 1.0000e-04
# Epoch 15/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 260ms/step - accuracy: 0.3906 - loss: 1.4300 - val_accuracy: 0.4332 - val_loss: 1.3688 - learning_rate: 1.0000e-04
# Epoch 16/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.3944 - loss: 1.4267 - val_accuracy: 0.4434 - val_loss: 1.3570 - learning_rate: 1.0000e-04
# Epoch 17/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 258ms/step - accuracy: 0.4144 - loss: 1.3922 - val_accuracy: 0.4752 - val_loss: 1.3083 - learning_rate: 1.0000e-04
# Epoch 18/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 0.4264 - loss: 1.3677 - val_accuracy: 0.4764 - val_loss: 1.2878 - learning_rate: 1.0000e-04
# Epoch 19/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 0.4234 - loss: 1.3690 - val_accuracy: 0.5044 - val_loss: 1.2713 - learning_rate: 1.0000e-04
# Epoch 20/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 0.4486 - loss: 1.3402 - val_accuracy: 0.5078 - val_loss: 1.2497 - learning_rate: 1.0000e-04
# Epoch 21/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 282ms/step - accuracy: 0.4458 - loss: 1.3259 - val_accuracy: 0.5410 - val_loss: 1.1983 - learning_rate: 1.0000e-04
# Epoch 22/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 266ms/step - accuracy: 0.4618 - loss: 1.2926 - val_accuracy: 0.5644 - val_loss: 1.1651 - learning_rate: 1.0000e-04
# Epoch 23/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.4822 - loss: 1.2627 - val_accuracy: 0.5622 - val_loss: 1.1458 - learning_rate: 1.0000e-04
# Epoch 24/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 12s 290ms/step - accuracy: 0.4850 - loss: 1.2524 - val_accuracy: 0.5744 - val_loss: 1.1102 - learning_rate: 1.0000e-04
# Epoch 25/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.4914 - loss: 1.2243 - val_accuracy: 0.6122 - val_loss: 1.0714 - learning_rate: 1.0000e-04
# Epoch 26/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 38s 942ms/step - accuracy: 0.5180 - loss: 1.1827 - val_accuracy: 0.6134 - val_loss: 1.0463 - learning_rate: 1.0000e-04
# Epoch 27/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 12s 290ms/step - accuracy: 0.5316 - loss: 1.1605 - val_accuracy: 0.6432 - val_loss: 1.0072 - learning_rate: 1.0000e-04
# Epoch 28/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 278ms/step - accuracy: 0.5494 - loss: 1.1314 - val_accuracy: 0.6724 - val_loss: 0.9489 - learning_rate: 1.0000e-04
# Epoch 29/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.5612 - loss: 1.1102 - val_accuracy: 0.6758 - val_loss: 0.9360 - learning_rate: 1.0000e-04
# Epoch 30/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.5854 - loss: 1.0516 - val_accuracy: 0.7042 - val_loss: 0.8747 - learning_rate: 1.0000e-04
# Epoch 31/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.6016 - loss: 1.0208 - val_accuracy: 0.7262 - val_loss: 0.8325 - learning_rate: 1.0000e-04
# Epoch 32/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 0.6024 - loss: 1.0101 - val_accuracy: 0.7484 - val_loss: 0.7979 - learning_rate: 1.0000e-04
# Epoch 33/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 264ms/step - accuracy: 0.6280 - loss: 0.9550 - val_accuracy: 0.7524 - val_loss: 0.7517 - learning_rate: 1.0000e-04
# Epoch 34/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 264ms/step - accuracy: 0.6326 - loss: 0.9443 - val_accuracy: 0.7758 - val_loss: 0.7241 - learning_rate: 1.0000e-04
# Epoch 35/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.6580 - loss: 0.8794 - val_accuracy: 0.8080 - val_loss: 0.6477 - learning_rate: 1.0000e-04
# Epoch 36/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 280ms/step - accuracy: 0.6704 - loss: 0.8599 - val_accuracy: 0.8224 - val_loss: 0.6078 - learning_rate: 1.0000e-04
# Epoch 37/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 278ms/step - accuracy: 0.6942 - loss: 0.8091 - val_accuracy: 0.8368 - val_loss: 0.5720 - learning_rate: 1.0000e-04
# Epoch 38/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 267ms/step - accuracy: 0.6980 - loss: 0.7888 - val_accuracy: 0.8548 - val_loss: 0.5267 - learning_rate: 1.0000e-04
# Epoch 39/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.7224 - loss: 0.7307 - val_accuracy: 0.8618 - val_loss: 0.5027 - learning_rate: 1.0000e-04
# Epoch 40/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step - accuracy: 0.7224 - loss: 0.7354 - val_accuracy: 0.8868 - val_loss: 0.4634 - learning_rate: 1.0000e-04
# Epoch 41/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 267ms/step - accuracy: 0.7372 - loss: 0.6963 - val_accuracy: 0.8936 - val_loss: 0.4171 - learning_rate: 1.0000e-04
# Epoch 42/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.7694 - loss: 0.6368 - val_accuracy: 0.9152 - val_loss: 0.3777 - learning_rate: 1.0000e-04
# Epoch 43/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.7858 - loss: 0.5977 - val_accuracy: 0.9186 - val_loss: 0.3540 - learning_rate: 1.0000e-04
# Epoch 44/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 280ms/step - accuracy: 0.7934 - loss: 0.5659 - val_accuracy: 0.9072 - val_loss: 0.3670 - learning_rate: 1.0000e-04
# Epoch 45/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step - accuracy: 0.7912 - loss: 0.5715 - val_accuracy: 0.9268 - val_loss: 0.3187 - learning_rate: 1.0000e-04
# Epoch 46/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.7952 - loss: 0.5499 - val_accuracy: 0.9426 - val_loss: 0.2847 - learning_rate: 1.0000e-04
# Epoch 47/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.8238 - loss: 0.4969 - val_accuracy: 0.9520 - val_loss: 0.2573 - learning_rate: 1.0000e-04
# Epoch 48/48
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 279ms/step - accuracy: 0.8244 - loss: 0.4803 - val_accuracy: 0.9578 - val_loss: 0.2298 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 48.

# %%
plt.style.use('dark_background')

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
model.save('model_file.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
